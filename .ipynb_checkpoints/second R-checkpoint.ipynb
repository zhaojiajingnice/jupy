# %%
median(c(1,2,3)) 
var(c(1,2,3))
sd(c(1,2,3))
summary(c(1,2,3))
# Out:
# [1] 2
# [1] 1
# [1] 1
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     1.0     1.5     2.0     2.0     2.5     3.0

# %% [markdown]
# IQR 四分位距 25%-75%

# %%
hist(airquality$Wind,xlab="wind")
boxplot(airquality$Wind,xlab="wind",ylab="Speed(mph)")
# Out:
# Plot with title "Histogram of airquality$Wind"
# plot without title

# %%
boxplot(Wind~Month,airquality,xlab="Month",ylab="Speed(mph)")
# Out:
# plot without title

# %%
plot(airquality$Wind,airquality$Temp,main="title")
# with(airquality,plot(Wind,Temp)) #the same 
#title(main="title")
# Out:
# Plot with title "title"

# %%
with(airquality,
    plot(Wind,Temp,
         main="Wind and Temp in NYC",
         type="n"))#blank graph

with(subset(airquality,Month==9),
    points(Wind,Temp,col="red"))

with(subset(airquality,Month==5),
    points(Wind,Temp,col="blue"))

with(subset(airquality,Month%in%c(6,7,8)),
    points(Wind,Temp,col="black"))

#拟合
fit<-lm(Temp~Wind,airquality)
abline(fit,lwd=1)

legend(
    "topright",pch=1,
       col=c("red","blue","black"),
       legend=c("Sep","May","other")
        )
# Out:
# Plot with title "Wind and Temp in NYC"

# %%
#par redefine #mcolr
par("mfrow"=c(1,2))
hist(airquality$Temp)
hist(airquality$Wind)

par("mfrow"=c(1,1))
hist(airquality$Temp)

par("mfcol"=c(2,1))
hist(airquality$Temp)
hist(airquality$Wind)
# Out:
# Plot with title "Histogram of airquality$Wind"
# Plot with title "Histogram of airquality$Wind"

# %%
#lattice graph
library(lattice)
xyplot(Temp~Ozone,data=airquality,col="red")
# Out:
# plot without title

# %%
library(lattice)
xyplot(Temp~Ozone|Month,data=airquality,
      layout=c(5,1))
# Out:
# plot without title

# %%
q<-xyplot(Temp~Wind,data=airquality)
print(q)
# Out:
# plot without title

# %%
set.seed(1)
x<-rnorm(100)
f<-rep(0:1,each=50)
y<-x+f-f*x+rnorm(100,sd=0.5)
f<-factor(f,labels=c("group1","group2"))
xyplot(y~x|f,layout=c(2,1))

xyplot(
      y~x|f,
      panel=function(x,y){
          panel.xyplot(x,y)
          panel.abline(v=mean(x),h=mean(y),lty=2)
          panel.lmline(x,y,col="red")
      }
      )
# Out:
# plot without title
# plot without title

# %%
library(ggplot2)
qplot(Wind,Temp,data=airquality,color=Month)
qplot(Wind,Temp,data=airquality,size=Month)#size
airquality$Month<-factor(airquality$Month)
qplot(Wind,Temp,data=airquality,color=I("red"))
# Out:
# Warning message:
# "Using size for a discrete variable is not advised."
# plot without title
# plot without title
# plot without title

# %%
library(ggplot2)
qplot(Wind,Temp,data=airquality,size=I(3),
     xlab="Wind(mph)",
     ylab="T",
     main="hehe"    
     )#size
# Out:
# plot without title

# %%
library(ggplot2)
qplot(Wind,Temp,data=airquality,
     geom=c("point","smooth"))#grey 置信区间

qplot(Wind,Temp,data=airquality,
     geom=c("point","smooth"),
     color=Month)
# Out:
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# plot without title
# plot without title

# %%
library(ggplot2)
qplot(Wind,Temp,data=airquality,
     facets=.~Month)

qplot(Wind,Temp,data=airquality,
     facets=Month~.)
# Out:
# plot without title
# plot without title

# %%
library(ggplot2)
qplot(Temp,data=airquality,
#     facets=Month~.
     )#qplot will guess one parametre as box

qplot(y=Wind,data=airquality)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
library(ggplot2)


qplot(Wind,data=airquality,fill=Month)

qplot(Wind,data=airquality,geom="density",
#      color=Month
     )

qplot(Wind,data=airquality,geom="dotplot",
      #      color=Month
     )
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# `stat_bindot()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
library(ggplot2)
ggplot(airquality,aes(Wind,Temp)) +
 geom_point(   #color="steelblue",
        aes( color=factor(Month) ),
            alpha=0.4,
            size=5)#layer to layers
# Out:
# plot without title

# %%
library(ggplot2)
ggplot(airquality,
      aes(Wind,Temp,col=factor(Month)))+
 geom_point()+
 #stat_smooth(method="lm",se=FALSE,aes(group=1))+
 stat_smooth(method="lm",se=FALSE)
# Out:
# plot without title

# %%
library(RColorBrewer)
myColors<-c(brewer.pal(5,"Dark2"),"black")
display.brewer.pal(5,"Dark2")

library(ggplot2)

ggplot(airquality,
      aes(Wind,Temp,col=factor(Month)))+
 geom_point()+
 #stat_smooth(method="lm",se=FALSE,aes(group=1,col="All"))+
 stat_smooth(method="lm",se=FALSE)+
 scale_color_manual("Month",values=myColors)+
 facet_grid(.~Month)
 #+ theme_classic()
# Out:
# plot without title
# plot without title

# %%
 getwd()
pdf(file="f.pdf")
with(airquality,plot(Wind,Temp,
                    main="main"))
dev.off()
# Out:
# [1] "D:/jupy"
# png
#   2

# %%
#copy and save
with(airquality,plot(Wind,Temp,
                    main="main"))
dev.copy(png,file="save.png")

dev.off()
# Out:
# png
#   3
# png
#   2
# Plot with title "main"
